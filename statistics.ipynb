# %%
1. A probability density function (PDF) is a statistical measure that calculates the likelihood that a random variable will fall within a certain range of values
# Out:
#   Cell In[1], line 1
#     1. A probability density function (PDF) is a statistical measure that calculates the likelihood that a random variable will fall within a certain range of values
#        ^
# SyntaxError: invalid syntax

# %%
There are different types of probability distribution function

1. Binomial ditribution

2. Possion distribution

3. Gaussin distribution

4. Normal distribution
# Out:
#   Cell In[2], line 1
#     There are different types of probability distribution function
#           ^
# SyntaxError: invalid syntax

# %%
from scipy.stats import norm 
import numpy as np 

data_start = -8

data_end = 16

data_points = 8

data = np.linspace(data_start, data_end, data_points) 

mean = np.mean(data) 

std = np.std(data) 

probability_pdf = norm.pdf(4 , loc=mean , scale=std)
print(probability_pdf)
# Out:
# 0.050782866607162865

# %%
The Properties of binomial distribution are:
    
1. There are fixed possible trails
2. There are only two posssible outcomes
3. The probability of success remains constant for each trial
# Out:
#   Cell In[15], line 1
#     The Properties of binomial distribution are:
#         ^
# SyntaxError: invalid syntax

# %%
from scipy.stats import binom 
 
n = 4
p = 0.4

r_values = list(range(n + 1)) 

mean, var = binom.stats(n, p) 

dist = [binom.pmf(r, n, p) for r in r_values ] 

print("r\tp(r)") 

for i in range(n + 1): 
	
    print(str(r_values[i]) + "\t" + str(dist[i])) 

    print("mean = "+str(mean)) 

    print("variance = "+str(var))
# Out:
# r	p(r)
# 0	0.0040960000000000015
# mean = 3.5999999999999996
# variance = 1.44
# 1	0.03686400000000002
# mean = 3.5999999999999996
# variance = 1.44
# 2	0.1382400000000001
# mean = 3.5999999999999996
# variance = 1.44
# 3	0.2764800000000001
# mean = 3.5999999999999996
# variance = 1.44
# 4	0.3110400000000001
# mean = 3.5999999999999996
# variance = 1.44
# 5	0.1866240000000001
# mean = 3.5999999999999996
# variance = 1.44
# 6	0.04665599999999999
# mean = 3.5999999999999996
# variance = 1.44

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
# %matplotlib inline 

N = 400

data = np.random.randn(N) 

count, bins_count = np.histogram(data, bins=10) 

pdf = count / sum(count) 

cdf = np.cumsum(pdf) 

plt.plot(bins_count[1:], pdf, color="black", label="PDF") 

plt.plot(bins_count[1:], cdf, label="CDF") 

plt.legend()

# %%
Binomila distribution - Binomial distribution is the one in which the number of outcomes are only two, that is success or failure

Poisson dsitribution - Poisson distribution: Poisson distribution is the one in which the number of possible outcomes has no limits
# Out:
#   Cell In[34], line 1
#     Binomila distribution - Binomial distribution is the one in which the number of outcomes are only two, that is success or failure
#              ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt


s = np.random.poisson(10, 1000)

count, bins, ignored = plt.hist(s, 10, density=True)

plt.show()

# %%
 9.The mean of the binomial distribution is always equal to p, and the variance is always equal to pq/N
# Out:
#   Cell In[46], line 1
#     9.The mean of the binomial distribution is always equal to p, and the variance is always equal to pq/N
#      ^
# SyntaxError: invalid decimal literal
